# %% [markdown]
# # PyEcharts 简介

# %% [markdown]
# Echarts 是一个由百度开源的数据可视化，凭借着良好的交互性，精巧的图表设计，得到了众多开发者的认可。
#
# 而 Python 是一门富有表达力的语言，很适合用于数据处理。
#
# 为了能在python上使用echarts，pyecharts 诞生了。
#
# 使用 pyecharts 可以生成独立的网页，也可以在 flask , Django 中集成使用

# %% [markdown]
# # pyecharts包含的图表

# %% [markdown]
#    Bar（柱状图/条形图）
#
# 　　Bar3D（3D 柱状图）
#
# 　　Boxplot（箱形图）
#
# 　　EffectScatter（带有涟漪特效动画的散点图）
#
# 　　Funnel（漏斗图）
#
# 　　Gauge（仪表盘）
#
# 　　Geo（地理坐标系）
#
# 　　Graph（关系图）
#
# 　　HeatMap（热力图）
#
# 　　Kline（K线图）
#
# 　　Line（折线/面积图）
#
# 　　Line3D（3D 折线图）
#
# 　　Liquid（水球图）
#
# 　　Map（地图）
#
# 　　Parallel（平行坐标系）
#
# 　　Pie（饼图）
#
# 　　Polar（极坐标系）
#
# 　　Radar（雷达图）
#
# 　　Sankey（桑基图）
#
# 　　Scatter（散点图）
#
# 　　Scatter3D（3D 散点图）
#
# 　　ThemeRiver（主题河流图）
#
# 　　WordCloud（词云图）

# %% [markdown]
# # 主要参数说明

# %% [markdown]
# add()    主要方法，用于添加图表的数据和设置各种配置项
#
# show_config()    打印输出图表的所有配置项
#
# render()    默认将会在根目录下生成一个 render.html 的文件，支持 path 参数，设置文件保存位置，如 render(r"e:my_first_chart.html")，文件用浏览器打开。
#
# 基本上所有的图表类型都是这样绘制的：
#
# chart_name = Type() 初始化具体类型图表。
#
# add() 加数据及配置项。
#
# render() 生成 .html 文件。

# %% [markdown]
# # 绘图模块

# %% [markdown]
# ## 柱状图

# %%
from pyecharts.charts import Bar

c = (Bar().add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]).add_yaxis("商家A", [5, 20, 36, 10, 75, 90]))
# render 会生成本地 HTML 文件，默认会在当前目录生成 render.html 文件
# 也可以传入路径参数，如 bar.render("mycharts.html")
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3896f166a2f34898b04227e6a28c5ba7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3896f166a2f34898b04227e6a28c5ba7 = echarts.init(
#                     document.getElementById('3896f166a2f34898b04227e6a28c5ba7'), 'white', {renderer: 'canvas'});
#                 var option_3896f166a2f34898b04227e6a28c5ba7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_3896f166a2f34898b04227e6a28c5ba7.setOption(option_3896f166a2f34898b04227e6a28c5ba7);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values())
    .add_yaxis("商家B", Faker.values())
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar-MarkLine（指定类型）"))
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=False),
        markline_opts=opts.MarkLineOpts(
            data=[
                opts.MarkLineItem(type_="min", name="最小值"),
                opts.MarkLineItem(type_="max", name="最大值"),
                opts.MarkLineItem(type_="average", name="平均值"),
            ]
        ),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c2188e32fc0448319970047403a72f8b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c2188e32fc0448319970047403a72f8b = echarts.init(
#                     document.getElementById('c2188e32fc0448319970047403a72f8b'), 'white', {renderer: 'canvas'});
#                 var option_c2188e32fc0448319970047403a72f8b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 75,
#                 52,
#                 116,
#                 137,
#                 38,
#                 63,
#                 120
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "legendHoverLink": true,
#             "data": [
#                 81,
#                 21,
#                 129,
#                 148,
#                 125,
#                 71,
#                 29
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-MarkLine\uff08\u6307\u5b9a\u7c7b\u578b\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_c2188e32fc0448319970047403a72f8b.setOption(option_c2188e32fc0448319970047403a72f8b);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values(), stack="stack1")
    .add_yaxis("商家B", Faker.values(), stack="stack1")
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar-堆叠数据（全部）"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3f90002c7ab54b45be0401ef289a8e2e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3f90002c7ab54b45be0401ef289a8e2e = echarts.init(
#                     document.getElementById('3f90002c7ab54b45be0401ef289a8e2e'), 'white', {renderer: 'canvas'});
#                 var option_3f90002c7ab54b45be0401ef289a8e2e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 148,
#                 84,
#                 51,
#                 33,
#                 65,
#                 76,
#                 45
#             ],
#             "showBackground": false,
#             "stack": "stack1",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "legendHoverLink": true,
#             "data": [
#                 116,
#                 102,
#                 123,
#                 67,
#                 72,
#                 46,
#                 124
#             ],
#             "showBackground": false,
#             "stack": "stack1",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-\u5806\u53e0\u6570\u636e\uff08\u5168\u90e8\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_3f90002c7ab54b45be0401ef289a8e2e.setOption(option_3f90002c7ab54b45be0401ef289a8e2e);
#         });
#     </script>

# %% [markdown]
# ## 饼图

# %%
from pyecharts.charts import Pie

attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
v1 = [11, 12, 13, 10, 10, 10]
data_pair = [list(z) for z in zip(attr, v1)]
pie = Pie()
pie.add(series_name="单品销售分析",
        data_pair=data_pair)
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="97fb2e7a05ad48f8be139709145dae0b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_97fb2e7a05ad48f8be139709145dae0b = echarts.init(
#                     document.getElementById('97fb2e7a05ad48f8be139709145dae0b'), 'white', {renderer: 'canvas'});
#                 var option_97fb2e7a05ad48f8be139709145dae0b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u5355\u54c1\u9500\u552e\u5206\u6790",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u7f8a\u6bdb\u886b",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u96ea\u7eba\u886b",
#                     "value": 13
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 10
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     }
# };
#                 chart_97fb2e7a05ad48f8be139709145dae0b.setOption(option_97fb2e7a05ad48f8be139709145dae0b);
#         });
#     </script>

# %%
from pyecharts.charts import Pie

attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
v1 = [11, 12, 13, 10, 10, 10]
data_pair = [list(z) for z in zip(attr, v1)]
pie = Pie()
pie.add(series_name="单品销售分析",
        data_pair=data_pair,
        radius=[80, 180]
       )
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8d59b1291b824b5b9e92c457236408cd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8d59b1291b824b5b9e92c457236408cd = echarts.init(
#                     document.getElementById('8d59b1291b824b5b9e92c457236408cd'), 'white', {renderer: 'canvas'});
#                 var option_8d59b1291b824b5b9e92c457236408cd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u5355\u54c1\u9500\u552e\u5206\u6790",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u7f8a\u6bdb\u886b",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u96ea\u7eba\u886b",
#                     "value": 13
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 10
#                 }
#             ],
#             "radius": [
#                 80,
#                 180
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     }
# };
#                 chart_8d59b1291b824b5b9e92c457236408cd.setOption(option_8d59b1291b824b5b9e92c457236408cd);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie
x=['程序员','教师','医生','护士','警察','老板','律师','翻译','运动员']
y=[18,5,3,4,8,2,2,5,1]
pie = (
    Pie()
    .add('高中同学职业占比',[(i,j)for i,j in zip(x,y)])
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Pie-Legend 滚动"),
        legend_opts=opts.LegendOpts(type_="scroll", pos_left="80%", orient="vertical"),
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="cacd0555cbbf4662b48b687027a1264d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_cacd0555cbbf4662b48b687027a1264d = echarts.init(
#                     document.getElementById('cacd0555cbbf4662b48b687027a1264d'), 'white', {renderer: 'canvas'});
#                 var option_cacd0555cbbf4662b48b687027a1264d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u9ad8\u4e2d\u540c\u5b66\u804c\u4e1a\u5360\u6bd4",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u7a0b\u5e8f\u5458",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u6559\u5e08",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u533b\u751f",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u62a4\u58eb",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u8b66\u5bdf",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u8001\u677f",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5f8b\u5e08",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u7ffb\u8bd1",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u8fd0\u52a8\u5458",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7a0b\u5e8f\u5458",
#                 "\u6559\u5e08",
#                 "\u533b\u751f",
#                 "\u62a4\u58eb",
#                 "\u8b66\u5bdf",
#                 "\u8001\u677f",
#                 "\u5f8b\u5e08",
#                 "\u7ffb\u8bd1",
#                 "\u8fd0\u52a8\u5458"
#             ],
#             "selected": {},
#             "type": "scroll",
#             "show": true,
#             "left": "80%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Pie-Legend \u6eda\u52a8",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_cacd0555cbbf4662b48b687027a1264d.setOption(option_cacd0555cbbf4662b48b687027a1264d);
#         });
#     </script>

# %% [markdown]
# 玫瑰花饼图

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie
x=['程序员','教师','医生','护士','警察','老板','律师','翻译','运动员']
y=[18,5,3,4,8,2,2,5,1]
pie = (
    Pie()
   .add(
        "",
        [(i,j)for i,j in zip(x,y)],
        radius=["30%", "75%"],
        center=["25%", "50%"],
        rosetype="radius",
        label_opts=opts.LabelOpts(is_show=False),
    )
    .add(
        "",
        [(i,j)for i,j in zip(x,y)],
        radius=["30%", "75%"],
        center=["75%", "50%"],
        rosetype="area",
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="Pie-玫瑰图示例"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="78c2a47a85d64207a35bd758b192d22a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_78c2a47a85d64207a35bd758b192d22a = echarts.init(
#                     document.getElementById('78c2a47a85d64207a35bd758b192d22a'), 'white', {renderer: 'canvas'});
#                 var option_78c2a47a85d64207a35bd758b192d22a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u7a0b\u5e8f\u5458",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u6559\u5e08",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u533b\u751f",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u62a4\u58eb",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u8b66\u5bdf",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u8001\u677f",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5f8b\u5e08",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u7ffb\u8bd1",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u8fd0\u52a8\u5458",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "25%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u7a0b\u5e8f\u5458",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u6559\u5e08",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u533b\u751f",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u62a4\u58eb",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u8b66\u5bdf",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u8001\u677f",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5f8b\u5e08",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u7ffb\u8bd1",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u8fd0\u52a8\u5458",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "75%",
#                 "50%"
#             ],
#             "roseType": "area",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7a0b\u5e8f\u5458",
#                 "\u6559\u5e08",
#                 "\u533b\u751f",
#                 "\u62a4\u58eb",
#                 "\u8b66\u5bdf",
#                 "\u8001\u677f",
#                 "\u5f8b\u5e08",
#                 "\u7ffb\u8bd1",
#                 "\u8fd0\u52a8\u5458"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Pie-\u73ab\u7470\u56fe\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_78c2a47a85d64207a35bd758b192d22a.setOption(option_78c2a47a85d64207a35bd758b192d22a);
#         });
#     </script>

# %% [markdown]
# ## 箱体图-Boxplot

# %%
from pyecharts import options as opts
from pyecharts.charts import Boxplot
v1 = [
    [850, 740, 900, 1070, 930, 850, 950, 980, 980, 880, 1000, 980],
    [960, 940, 960, 940, 880, 800, 850, 880, 900, 840, 830, 790],
]
v2 = [
    [289, 281, 210, 282,280, 370, 270, 374, 270, 376, 290, 392],
    [80, 40, 80, 80, 60, 10, 70, 10, 80, 80, 80, 80],
]
c = Boxplot(init_opts=opts.InitOpts(width="800px", height="500px")) #设置大小
c.add_xaxis(["expr1", "expr2"]) 
c.add_yaxis("A组", c.prepare_data(v1)) #这个和之前不一样 
c.add_yaxis("B组", c.prepare_data(v2))
c.set_global_opts(title_opts=opts.TitleOpts(title="BoxPlot-基本示例"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9780fd476ab8488aacf0832c334d3e3f" style="width:800px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9780fd476ab8488aacf0832c334d3e3f = echarts.init(
#                     document.getElementById('9780fd476ab8488aacf0832c334d3e3f'), 'white', {renderer: 'canvas'});
#                 var option_9780fd476ab8488aacf0832c334d3e3f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "A\u7ec4",
#             "data": [
#                 [
#                     740,
#                     857.5,
#                     940.0,
#                     980.0,
#                     1070
#                 ],
#                 [
#                     790,
#                     832.5,
#                     880.0,
#                     940.0,
#                     960
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         },
#         {
#             "type": "boxplot",
#             "name": "B\u7ec4",
#             "data": [
#                 [
#                     210,
#                     272.5,
#                     285.5,
#                     373.0,
#                     392
#                 ],
#                 [
#                     10,
#                     45.0,
#                     80.0,
#                     80.0,
#                     80
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A\u7ec4",
#                 "B\u7ec4"
#             ],
#             "selected": {
#                 "A\u7ec4": true,
#                 "B\u7ec4": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "expr1",
#                 "expr2"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "BoxPlot-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_9780fd476ab8488aacf0832c334d3e3f.setOption(option_9780fd476ab8488aacf0832c334d3e3f);
#         });
#     </script>

# %% [markdown]
# ## 折线图-Line

# %%
import pyecharts.options as opts
from pyecharts.charts import Line
x=['星期一','星期二','星期三','星期四','星期五','星期七','星期日']
y1=[100,200,300,400,100,400,300]
y2=[200,300,200,100,200,300,400]
line=(
    Line()
    .add_xaxis(xaxis_data=x)
    .add_yaxis(series_name="y1线",y_axis=y1,symbol="arrow",is_symbol_show=True)
    .add_yaxis(series_name="y2线",y_axis=y2)
    .set_global_opts(title_opts=opts.TitleOpts(title="Line-多折线重叠"))
)
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2f3b79d46cc34133a76bd83178f872cc" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2f3b79d46cc34133a76bd83178f872cc = echarts.init(
#                     document.getElementById('2f3b79d46cc34133a76bd83178f872cc'), 'white', {renderer: 'canvas'});
#                 var option_2f3b79d46cc34133a76bd83178f872cc = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "y1\u7ebf",
#             "connectNulls": false,
#             "symbol": "arrow",
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u661f\u671f\u4e00",
#                     100
#                 ],
#                 [
#                     "\u661f\u671f\u4e8c",
#                     200
#                 ],
#                 [
#                     "\u661f\u671f\u4e09",
#                     300
#                 ],
#                 [
#                     "\u661f\u671f\u56db",
#                     400
#                 ],
#                 [
#                     "\u661f\u671f\u4e94",
#                     100
#                 ],
#                 [
#                     "\u661f\u671f\u4e03",
#                     400
#                 ],
#                 [
#                     "\u661f\u671f\u65e5",
#                     300
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "y2\u7ebf",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u661f\u671f\u4e00",
#                     200
#                 ],
#                 [
#                     "\u661f\u671f\u4e8c",
#                     300
#                 ],
#                 [
#                     "\u661f\u671f\u4e09",
#                     200
#                 ],
#                 [
#                     "\u661f\u671f\u56db",
#                     100
#                 ],
#                 [
#                     "\u661f\u671f\u4e94",
#                     200
#                 ],
#                 [
#                     "\u661f\u671f\u4e03",
#                     300
#                 ],
#                 [
#                     "\u661f\u671f\u65e5",
#                     400
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "y1\u7ebf",
#                 "y2\u7ebf"
#             ],
#             "selected": {
#                 "y1\u7ebf": true,
#                 "y2\u7ebf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u661f\u671f\u4e00",
#                 "\u661f\u671f\u4e8c",
#                 "\u661f\u671f\u4e09",
#                 "\u661f\u671f\u56db",
#                 "\u661f\u671f\u4e94",
#                 "\u661f\u671f\u4e03",
#                 "\u661f\u671f\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Line-\u591a\u6298\u7ebf\u91cd\u53e0",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_2f3b79d46cc34133a76bd83178f872cc.setOption(option_2f3b79d46cc34133a76bd83178f872cc);
#         });
#     </script>

# %%
import pyecharts.options as opts
from pyecharts.charts import Line
x=['星期一','星期二','星期三','星期四','星期五','星期七','星期日']
y1=[100,200,300,400,100,400,300]
y2=[200,300,200,100,200,300,400]
line=(
    Line()
    .add_xaxis(xaxis_data=x)
    .add_yaxis(series_name="y1线",y_axis=y1, is_smooth=True)
    .add_yaxis(series_name="y2线",y_axis=y2, is_smooth=True)
    .set_global_opts(title_opts=opts.TitleOpts(title="Line-多折线重叠"))
)
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="991254a2212d4e999cf7102b64cc2fdf" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_991254a2212d4e999cf7102b64cc2fdf = echarts.init(
#                     document.getElementById('991254a2212d4e999cf7102b64cc2fdf'), 'white', {renderer: 'canvas'});
#                 var option_991254a2212d4e999cf7102b64cc2fdf = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "y1\u7ebf",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u661f\u671f\u4e00",
#                     100
#                 ],
#                 [
#                     "\u661f\u671f\u4e8c",
#                     200
#                 ],
#                 [
#                     "\u661f\u671f\u4e09",
#                     300
#                 ],
#                 [
#                     "\u661f\u671f\u56db",
#                     400
#                 ],
#                 [
#                     "\u661f\u671f\u4e94",
#                     100
#                 ],
#                 [
#                     "\u661f\u671f\u4e03",
#                     400
#                 ],
#                 [
#                     "\u661f\u671f\u65e5",
#                     300
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "y2\u7ebf",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u661f\u671f\u4e00",
#                     200
#                 ],
#                 [
#                     "\u661f\u671f\u4e8c",
#                     300
#                 ],
#                 [
#                     "\u661f\u671f\u4e09",
#                     200
#                 ],
#                 [
#                     "\u661f\u671f\u56db",
#                     100
#                 ],
#                 [
#                     "\u661f\u671f\u4e94",
#                     200
#                 ],
#                 [
#                     "\u661f\u671f\u4e03",
#                     300
#                 ],
#                 [
#                     "\u661f\u671f\u65e5",
#                     400
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "y1\u7ebf",
#                 "y2\u7ebf"
#             ],
#             "selected": {
#                 "y1\u7ebf": true,
#                 "y2\u7ebf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u661f\u671f\u4e00",
#                 "\u661f\u671f\u4e8c",
#                 "\u661f\u671f\u4e09",
#                 "\u661f\u671f\u56db",
#                 "\u661f\u671f\u4e94",
#                 "\u661f\u671f\u4e03",
#                 "\u661f\u671f\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Line-\u591a\u6298\u7ebf\u91cd\u53e0",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_991254a2212d4e999cf7102b64cc2fdf.setOption(option_991254a2212d4e999cf7102b64cc2fdf);
#         });
#     </script>

# %%
import pyecharts.options as opts
from pyecharts.charts import Line
x=['星期一','星期二','星期三','星期四','星期五','星期七','星期日']
y1=[100,200,300,400,100,400,300]
line=(
    Line()
    .add_xaxis(xaxis_data=x)
    .add_yaxis(series_name="y1线",y_axis=y1, is_step=True)
    .set_global_opts(title_opts=opts.TitleOpts(title="Line-阶梯图"))
)
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e3b8a0f9c40f4a6e9673b2a6708e9983" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e3b8a0f9c40f4a6e9673b2a6708e9983 = echarts.init(
#                     document.getElementById('e3b8a0f9c40f4a6e9673b2a6708e9983'), 'white', {renderer: 'canvas'});
#                 var option_e3b8a0f9c40f4a6e9673b2a6708e9983 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "y1\u7ebf",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": true,
#             "data": [
#                 [
#                     "\u661f\u671f\u4e00",
#                     100
#                 ],
#                 [
#                     "\u661f\u671f\u4e8c",
#                     200
#                 ],
#                 [
#                     "\u661f\u671f\u4e09",
#                     300
#                 ],
#                 [
#                     "\u661f\u671f\u56db",
#                     400
#                 ],
#                 [
#                     "\u661f\u671f\u4e94",
#                     100
#                 ],
#                 [
#                     "\u661f\u671f\u4e03",
#                     400
#                 ],
#                 [
#                     "\u661f\u671f\u65e5",
#                     300
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "y1\u7ebf"
#             ],
#             "selected": {
#                 "y1\u7ebf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u661f\u671f\u4e00",
#                 "\u661f\u671f\u4e8c",
#                 "\u661f\u671f\u4e09",
#                 "\u661f\u671f\u56db",
#                 "\u661f\u671f\u4e94",
#                 "\u661f\u671f\u4e03",
#                 "\u661f\u671f\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Line-\u9636\u68af\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_e3b8a0f9c40f4a6e9673b2a6708e9983.setOption(option_e3b8a0f9c40f4a6e9673b2a6708e9983);
#         });
#     </script>

# %% [markdown]
# ## 散点图

# %% [markdown]
# 基本散点图

# %%
from pyecharts import options as opts
from pyecharts.charts import Scatter
x=['一月','二月','三月','四月','五月','六月','七月','八月','九月']
y=[8,5,3,4,8,2,2,5,1]
c = (
    Scatter()
    .add_xaxis(x)
    .add_yaxis("", y)
    .set_global_opts(title_opts=opts.TitleOpts(title="base")
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ef2a36a48f3148a5957a3e7ef09cc3cf" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ef2a36a48f3148a5957a3e7ef09cc3cf = echarts.init(
#                     document.getElementById('ef2a36a48f3148a5957a3e7ef09cc3cf'), 'white', {renderer: 'canvas'});
#                 var option_ef2a36a48f3148a5957a3e7ef09cc3cf = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u4e00\u6708",
#                     8
#                 ],
#                 [
#                     "\u4e8c\u6708",
#                     5
#                 ],
#                 [
#                     "\u4e09\u6708",
#                     3
#                 ],
#                 [
#                     "\u56db\u6708",
#                     4
#                 ],
#                 [
#                     "\u4e94\u6708",
#                     8
#                 ],
#                 [
#                     "\u516d\u6708",
#                     2
#                 ],
#                 [
#                     "\u4e03\u6708",
#                     2
#                 ],
#                 [
#                     "\u516b\u6708",
#                     5
#                 ],
#                 [
#                     "\u4e5d\u6708",
#                     1
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4e00\u6708",
#                 "\u4e8c\u6708",
#                 "\u4e09\u6708",
#                 "\u56db\u6708",
#                 "\u4e94\u6708",
#                 "\u516d\u6708",
#                 "\u4e03\u6708",
#                 "\u516b\u6708",
#                 "\u4e5d\u6708"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "base",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_ef2a36a48f3148a5957a3e7ef09cc3cf.setOption(option_ef2a36a48f3148a5957a3e7ef09cc3cf);
#         });
#     </script>

# %% [markdown]
# 显示分割线散点图

# %%
from pyecharts import options as opts
from pyecharts.charts import Scatter
x=['一月','二月','三月','四月','五月','六月','七月','八月','九月']
y=[8,5,3,4,8,2,2,5,1]
c = (
    Scatter()
    .add_xaxis(x)
    .add_yaxis("", y)
    .set_global_opts(
        title_opts=opts.TitleOpts(title="base"),
        xaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True)),
        yaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True))
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7d2a7f79451042caa9135f174f95163d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7d2a7f79451042caa9135f174f95163d = echarts.init(
#                     document.getElementById('7d2a7f79451042caa9135f174f95163d'), 'white', {renderer: 'canvas'});
#                 var option_7d2a7f79451042caa9135f174f95163d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u4e00\u6708",
#                     8
#                 ],
#                 [
#                     "\u4e8c\u6708",
#                     5
#                 ],
#                 [
#                     "\u4e09\u6708",
#                     3
#                 ],
#                 [
#                     "\u56db\u6708",
#                     4
#                 ],
#                 [
#                     "\u4e94\u6708",
#                     8
#                 ],
#                 [
#                     "\u516d\u6708",
#                     2
#                 ],
#                 [
#                     "\u4e03\u6708",
#                     2
#                 ],
#                 [
#                     "\u516b\u6708",
#                     5
#                 ],
#                 [
#                     "\u4e5d\u6708",
#                     1
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4e00\u6708",
#                 "\u4e8c\u6708",
#                 "\u4e09\u6708",
#                 "\u56db\u6708",
#                 "\u4e94\u6708",
#                 "\u516d\u6708",
#                 "\u4e03\u6708",
#                 "\u516b\u6708",
#                 "\u4e5d\u6708"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "base",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_7d2a7f79451042caa9135f174f95163d.setOption(option_7d2a7f79451042caa9135f174f95163d);
#         });
#     </script>

# %% [markdown]
# 气泡散点图
#
# 参数介绍：
#
# range_opacity：设置透明度
#
# type：size，用形状大小代表数据大小
#
# is_piecewise：是否分段
#
# pieces：具体分段范围

# %%
from pyecharts import options as opts
from pyecharts.charts import Scatter
x=['一月','二月','三月','四月','五月','六月','七月','八月','九月']
y=[8,5,3,4,8,2,2,5,1]
c = (
    Scatter()
    .add_xaxis(x)
    .add_yaxis("", y)
    .set_global_opts(
        title_opts=opts.TitleOpts(title="气泡图"),
        visualmap_opts=opts.VisualMapOpts(
            range_opacity=0.45,
            type_="size", 
            max_=10,
            is_piecewise=True,
            dimension=0,
            pieces=[
                {"lte": 2, "color": "green"},
                {"gt": 2, "lte": 4, "color": "red"},
                {"gt": 4, "lte": 6, "color": "yellow"},
                {"gt": 6, "lte": 8, "color": "red"},
                {"gt": 8, "color": "green"},
            ],
            pos_right=0,
            pos_bottom=100)
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="769e3f41e2f74864a95d55023b299cb6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_769e3f41e2f74864a95d55023b299cb6 = echarts.init(
#                     document.getElementById('769e3f41e2f74864a95d55023b299cb6'), 'white', {renderer: 'canvas'});
#                 var option_769e3f41e2f74864a95d55023b299cb6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u4e00\u6708",
#                     8
#                 ],
#                 [
#                     "\u4e8c\u6708",
#                     5
#                 ],
#                 [
#                     "\u4e09\u6708",
#                     3
#                 ],
#                 [
#                     "\u56db\u6708",
#                     4
#                 ],
#                 [
#                     "\u4e94\u6708",
#                     8
#                 ],
#                 [
#                     "\u516d\u6708",
#                     2
#                 ],
#                 [
#                     "\u4e03\u6708",
#                     2
#                 ],
#                 [
#                     "\u516b\u6708",
#                     5
#                 ],
#                 [
#                     "\u4e5d\u6708",
#                     1
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4e00\u6708",
#                 "\u4e8c\u6708",
#                 "\u4e09\u6708",
#                 "\u56db\u6708",
#                 "\u4e94\u6708",
#                 "\u516d\u6708",
#                 "\u4e03\u6708",
#                 "\u516b\u6708",
#                 "\u4e5d\u6708"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6c14\u6ce1\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 10,
#         "inRange": {
#             "symbolSize": [
#                 20,
#                 50
#             ],
#             "opacity": 0.45
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "dimension": 0,
#         "orient": "vertical",
#         "bottom": 100,
#         "right": 0,
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0,
#         "pieces": [
#             {
#                 "lte": 2,
#                 "color": "green"
#             },
#             {
#                 "gt": 2,
#                 "lte": 4,
#                 "color": "red"
#             },
#             {
#                 "gt": 4,
#                 "lte": 6,
#                 "color": "yellow"
#             },
#             {
#                 "gt": 6,
#                 "lte": 8,
#                 "color": "red"
#             },
#             {
#                 "gt": 8,
#                 "color": "green"
#             }
#         ]
#     }
# };
#                 chart_769e3f41e2f74864a95d55023b299cb6.setOption(option_769e3f41e2f74864a95d55023b299cb6);
#         });
#     </script>

# %% [markdown]
# ## 雷达图

# %%
from pyecharts import options as opts
from pyecharts.charts import Radar

v1 = [[4300, 10000, 28000, 35000, 50000, 19000]]
v2 = [[5000, 14000, 28000, 31000, 42000, 21000]]
c = (
    Radar()
    .add_schema(
        schema=[
            opts.RadarIndicatorItem(name="销售", max_=6500),
            opts.RadarIndicatorItem(name="管理", max_=16000),
            opts.RadarIndicatorItem(name="信息技术", max_=30000),
            opts.RadarIndicatorItem(name="客服", max_=38000),
            opts.RadarIndicatorItem(name="研发", max_=52000),
            opts.RadarIndicatorItem(name="市场", max_=25000),
        ]
    )
    .add("预算分配", v1)
    .add("实际开销", v2)
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        legend_opts=opts.LegendOpts(selected_mode="single"),
        title_opts=opts.TitleOpts(title="Radar-单例模式"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2a1ffacde3c5462192f61de8bf8a6486" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2a1ffacde3c5462192f61de8bf8a6486 = echarts.init(
#                     document.getElementById('2a1ffacde3c5462192f61de8bf8a6486'), 'white', {renderer: 'canvas'});
#                 var option_2a1ffacde3c5462192f61de8bf8a6486 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "radar",
#             "name": "\u9884\u7b97\u5206\u914d",
#             "data": [
#                 [
#                     4300,
#                     10000,
#                     28000,
#                     35000,
#                     50000,
#                     19000
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u5b9e\u9645\u5f00\u9500",
#             "data": [
#                 [
#                     5000,
#                     14000,
#                     28000,
#                     31000,
#                     42000,
#                     21000
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9884\u7b97\u5206\u914d",
#                 "\u5b9e\u9645\u5f00\u9500"
#             ],
#             "selected": {
#                 "\u9884\u7b97\u5206\u914d": true,
#                 "\u5b9e\u9645\u5f00\u9500": true
#             },
#             "selectedMode": "single",
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "radar": {
#         "indicator": [
#             {
#                 "name": "\u9500\u552e",
#                 "max": 6500
#             },
#             {
#                 "name": "\u7ba1\u7406",
#                 "max": 16000
#             },
#             {
#                 "name": "\u4fe1\u606f\u6280\u672f",
#                 "max": 30000
#             },
#             {
#                 "name": "\u5ba2\u670d",
#                 "max": 38000
#             },
#             {
#                 "name": "\u7814\u53d1",
#                 "max": 52000
#             },
#             {
#                 "name": "\u5e02\u573a",
#                 "max": 25000
#             }
#         ],
#         "name": {
#             "textStyle": {}
#         },
#         "splitLine": {
#             "show": true,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             }
#         },
#         "splitArea": {
#             "show": true,
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         "axisLine": {
#             "show": true,
#             "onZero": true,
#             "onZeroAxisIndex": 0
#         }
#     },
#     "title": [
#         {
#             "text": "Radar-\u5355\u4f8b\u6a21\u5f0f",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_2a1ffacde3c5462192f61de8bf8a6486.setOption(option_2a1ffacde3c5462192f61de8bf8a6486);
#         });
#     </script>

# %% [markdown]
# ## 词云图

# %%
from pyecharts import options as opts
from pyecharts.charts import WordCloud
from pyecharts.globals import SymbolType


words = [
    ("深度学习", 10000),
    ("工业AI", 6181),
    ("Python", 4386),
    ("数据挖掘", 4186),
    ("目标检测", 3586),
    ("统计学习", 4055),
    ("LightGBM", 2467),
    ("XGBoost", 2244),
    ("智能制造", 1868),
    ("IoT", 1484),
    ("YOLO", 1112),
    ("半导体", 865),
    ("面板", 865),
    ("Pandas", 847),
    ("Numpy", 582),
    ("Hive", 555),
    ("数据挖掘", 550),
    ("LSTM", 462),
    ("CNN", 366),
    ("PySpark", 360),
    ("算法", 282),
    ("YoloV5", 273),
    ("Dert", 265),
]
c = (
    WordCloud()
    .add("", words, word_size_range=[20, 100], shape=SymbolType.DIAMOND)
    .set_global_opts(title_opts=opts.TitleOpts(title="WordCloud-shape-diamond"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="1234c11b9e04433f91b898f4c85ce4e3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_1234c11b9e04433f91b898f4c85ce4e3 = echarts.init(
#                     document.getElementById('1234c11b9e04433f91b898f4c85ce4e3'), 'white', {renderer: 'canvas'});
#                 var option_1234c11b9e04433f91b898f4c85ce4e3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u6df1\u5ea6\u5b66\u4e60",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(145,29,87)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5de5\u4e1aAI",
#                     "value": 6181,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(22,95,120)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Python",
#                     "value": 4386,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(46,116,42)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6570\u636e\u6316\u6398",
#                     "value": 4186,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(72,76,19)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u76ee\u6807\u68c0\u6d4b",
#                     "value": 3586,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(96,117,16)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7edf\u8ba1\u5b66\u4e60",
#                     "value": 4055,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(70,91,78)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "LightGBM",
#                     "value": 2467,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(146,148,20)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "XGBoost",
#                     "value": 2244,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(60,97,64)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u667a\u80fd\u5236\u9020",
#                     "value": 1868,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(63,76,142)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "IoT",
#                     "value": 1484,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(81,81,62)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "YOLO",
#                     "value": 1112,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(143,114,43)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u534a\u5bfc\u4f53",
#                     "value": 865,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(106,103,100)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9762\u677f",
#                     "value": 865,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(152,11,140)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Pandas",
#                     "value": 847,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(149,60,42)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Numpy",
#                     "value": 582,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(51,82,27)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Hive",
#                     "value": 555,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(78,83,48)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6570\u636e\u6316\u6398",
#                     "value": 550,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(113,8,70)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "LSTM",
#                     "value": 462,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(158,101,14)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "CNN",
#                     "value": 366,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(139,35,149)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "PySpark",
#                     "value": 360,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(57,47,90)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7b97\u6cd5",
#                     "value": 282,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(70,14,9)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "YoloV5",
#                     "value": 273,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(57,36,28)"

# %% [markdown]
# # Pycharts地图功能（选学）

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.faker import Faker
from pyecharts.globals import ChartType
provinces = ['四川','湖北','安徽','上海','广东','山东','福建','北京']
val = [40,15,25,15,5,20,10,5]

c = (
    Geo()
    .add_schema(maptype="china")
    .add(
        "区域分布",
        [list(z) for z in zip(provinces,val)],
        type_=ChartType.EFFECT_SCATTER,
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="中国"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="9a93a0cfbf944be98700030bfec126d9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_9a93a0cfbf944be98700030bfec126d9 = echarts.init(
#                     document.getElementById('9a93a0cfbf944be98700030bfec126d9'), 'white', {renderer: 'canvas'});
#                 var option_9a93a0cfbf944be98700030bfec126d9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": "\u533a\u57df\u5206\u5e03",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": [
#                         104.075931,
#                         30.651651,
#                         40
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": [
#                         114.341861,
#                         30.546498,
#                         15
#                     ]
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": [
#                         117.284922,
#                         31.861184,
#                         25
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         15
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         5
#                     ]
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": [
#                         117.020359,
#                         36.66853,
#                         20
#                     ]
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": [
#                         119.295144,
#                         26.100779,
#                         10
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         5
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u533a\u57df\u5206\u5e03"
#             ],
#             "selected": {
#                 "\u533a\u57df\u5206\u5e03": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u4e2d\u56fd",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "aspectScale": 0.75,
#         "nameProperty": "name",
#         "selectedMode": false,
#         "emphasis": {}
#     }
# };
#                 chart_9a93a0cfbf944be98700030bfec126d9.setOption(option_9a93a0cfbf944be98700030bfec126d9);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Map3D
from pyecharts.globals import ChartType
from pyecharts.commons.utils import JsCode

example_data = [
#     ("黑龙江", [127.9688, 45.368, 100]),
#     ("内蒙古", [110.3467, 41.4899, 100]),
#     ("吉林", [125.8154, 44.2584, 100]),
#     ("辽宁", [123.1238, 42.1216, 100]),
#     ("河北", [114.4995, 38.1006, 100]),
#     ("天津", [117.4219, 39.4189, 100]),
#     ("山西", [112.3352, 37.9413, 100]),
#     ("陕西", [109.1162, 34.2004, 100]),
#     ("甘肃", [103.5901, 36.3043, 100]),
#     ("宁夏", [106.3586, 38.1775, 100]),
#     ("青海", [101.4038, 36.8207, 100]),
#     ("新疆", [87.9236, 43.5883, 100]),
#     ("西藏", [91.11, 29.97, 100]),
    ("四川", [103.9526, 30.7617, 40]),
    ("重庆", [108.384366, 30.439702, 20]),
    ("山东", [117.1582, 36.8701, 20]),
    ("河南", [113.4668, 34.6234, 5]),
    ("江苏", [118.8062, 31.9208, 10]),
    ("安徽", [117.29, 32.0581, 20]),
    ("湖北", [114.3896, 30.6628, 15]),
    ("浙江", [119.5313, 29.8773, 5]),
    ("福建", [119.4543, 25.9222, 10]),
#     ("江西", [116.0046, 28.6633, 100]),
#     ("湖南", [113.0823, 28.2568, 100]),
#     ("贵州", [106.6992, 26.7682, 100]),
#     ("广西", [108.479, 23.1152, 100]),
#     ("海南", [110.3893, 19.8516, 100]),
    ("上海", [121.4648, 31.2891, 25]),
]

c = (
    Map3D()
    .add_schema(
        itemstyle_opts=opts.ItemStyleOpts(
            color="rgb(5,101,123)",
            opacity=1,
            border_width=0.8,
            border_color="rgb(62,215,213)",
        ),
        map3d_label=opts.Map3DLabelOpts(
            is_show=False,
            formatter=JsCode("function(data){return data.name + " " + data.value[2];}"),
        ),
        emphasis_label_opts=opts.LabelOpts(
            is_show=False,
            color="#fff",
            font_size=10,
            background_color="rgba(0,23,11,0)",
        ),
        light_opts=opts.Map3DLightOpts(
            main_color="#fff",
            main_intensity=1.2,
            main_shadow_quality="high",
            is_main_shadow=False,
            main_beta=10,
            ambient_intensity=0.3,
        ),
    )
    .add(
        series_name="Scatter3D",
        data_pair=example_data,
        type_=ChartType.SCATTER3D,
        bar_size=1,
        shading="lambert",
        label_opts=opts.LabelOpts(
            is_show=False,
            formatter=JsCode("function(data){return data.name + ' ' + data.value[2];}"),
        ),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="Map3D-Scatter3D"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/echarts-gl.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="6de5aa067ce8471ea716f86daeb7b248" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-gl', 'china'], function(echarts) {
#                 var chart_6de5aa067ce8471ea716f86daeb7b248 = echarts.init(
#                     document.getElementById('6de5aa067ce8471ea716f86daeb7b248'), 'white', {renderer: 'canvas'});
#                 var option_6de5aa067ce8471ea716f86daeb7b248 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter3D",
#             "name": "Scatter3D",
#             "coordinateSystem": "geo3D",
#             "grid3DIndex": 0,
#             "geo3DIndex": 0,
#             "globeIndex": 0,
#             "symbol": "circle",
#             "symbolSize": 10,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": function(data){return data.name + ' ' + data.value[2];}
#             },
#             "emphasis": {},
#             "data": [
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": [
#                         103.9526,
#                         30.7617,
#                         40
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         108.384366,
#                         30.439702,
#                         20
#                     ]
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": [
#                         117.1582,
#                         36.8701,
#                         20
#                     ]
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": [
#                         113.4668,
#                         34.6234,
#                         5
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": [
#                         118.8062,
#                         31.9208,
#                         10
#                     ]
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": [
#                         117.29,
#                         32.0581,
#                         20
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": [
#                         114.3896,
#                         30.6628,
#                         15
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": [
#                         119.5313,
#                         29.8773,
#                         5
#                     ]
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": [
#                         119.4543,
#                         25.9222,
#                         10
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.4648,
#                         31.2891,
#                         25
#                     ]
#                 }
#             ],
#             "blendMode": "source-over",
#             "zlevel": -10,
#             "silent": false,
#             "animation": true,
#             "animationDurationUpdate": 100,
#             "animationEasingUpdate": "cubicOut"
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Scatter3D"
#             ],
#             "selected": {
#                 "Scatter3D": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "geo3D": {
#         "map": "china",
#         "boxWidth": 100,
#         "boxHeight": 10,
#         "regionHeight": 3,
#         "groundPlane": {
#             "show": false,
#             "color": "#aaa"
#         },
#         "instancing": false,
#         "itemStyle": {
#             "color": "rgb(5,101,123)",
#             "borderColor": "rgb(62,215,213)",
#             "borderWidth": 0.8,
#             "opacity": 1
#         },
#         "label": {
#             "show": false,
#             "formatter": function(data){return data.name +  + data.value[2];}
#         },
#         "emphasis": {
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "color": "#fff",
#                 "margin": 8,
#                 "fontSize": 10,
#                 "backgroundColor": "rgba(0,23,11,0)"
#             }
#         },
#         "light": {
#             "main": {
#                 "color": "#fff",
#                 "intensity": 1.2,
#                 "shadow": false,
#                 "shadowQuality": "high",
#                 "alpha": 40,
#                 "beta": 10
#             },
#             "ambient": {
#                 "color": "#fff",
#                 "intensity": 0.3
#             },
#             "ambientCubemap": {
#                 "diffuseIntensity": 0.5,
#                 "specularIntensity": 0.5
#             }
#         },
#         "temporalSuperSampling": {
#             "enable": "auto"
#         },
#         "zlevel": -10,
#         "left": "auto",
#         "top": "auto",
#         "right": "auto",
#         "bottom": "auto",
#         "width": "auto",
#         "height": "auto"
#     },
#     "title": [
#         {
#             "text": "Map3D-Scatter3D",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_6de5aa067ce8471ea716f86daeb7b248.setOption(option_6de5aa067ce8471ea716f86daeb7b248);
#         });
#     </script>

# %%
import pyecharts.options as opts
from pyecharts.charts import MapGlobe
from pyecharts.faker import POPULATION
data = [x for _, x in POPULATION[1:]]
low, high = min(data), max(data)
c = (
    MapGlobe(init_opts=opts.InitOpts())
    .add_schema()
    .add(
        maptype="world",#world，china
        series_name="World Population",
        data_pair=POPULATION[1:],
        is_map_symbol_show=False,
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(
            min_=low,
            max_=high,
            range_text=["max", "min"],
            is_calculable=True,
            is_piecewise=True,
            range_color=["lightskyblue", "yellow", "orangered"],
        )
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/echarts-gl.min', 'china':'https://assets.pyecharts.org/assets/maps/china', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#     <div id="b4b0eecca9124c528ee8b9ac9c66e974" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'echarts-gl', 'china', 'world'], function(echarts) {
# 		var canvas_b4b0eecca9124c528ee8b9ac9c66e974 = document.createElement('canvas');
#         var mapChart_b4b0eecca9124c528ee8b9ac9c66e974 = echarts.init(
# 	    canvas_b4b0eecca9124c528ee8b9ac9c66e974, 'white', {width: 4096, height: 2048, renderer: 'canvas'});
#         var mapOption_b4b0eecca9124c528ee8b9ac9c66e974 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "World Population",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "China",
#                     "value": 1420062022
#                 },
#                 {
#                     "name": "India",
#                     "value": 1368737513
#                 },
#                 {
#                     "name": "United States",
#                     "value": 329093110
#                 },
#                 {
#                     "name": "Indonesia",
#                     "value": 269536482
#                 },
#                 {
#                     "name": "Brazil",
#                     "value": 212392717
#                 },
#                 {
#                     "name": "Pakistan",
#                     "value": 204596442
#                 },
#                 {
#                     "name": "Nigeria",
#                     "value": 200962417
#                 },
#                 {
#                     "name": "Bangladesh",
#                     "value": 168065920
#                 },
#                 {
#                     "name": "Russia",
#                     "value": 143895551
#                 },
#                 {
#                     "name": "Mexico",
#                     "value": 132328035
#                 },
#                 {
#                     "name": "Japan",
#                     "value": 126854745
#                 },
#                 {
#                     "name": "Ethiopia",
#                     "value": 110135635
#                 },
#                 {
#                     "name": "Philippines",
#                     "value": 108106310
#                 },
#                 {
#                     "name": "Egypt",
#                     "value": 101168745
#                 },
#                 {
#                     "name": "Vietnam",
#                     "value": 97429061
#                 },
#                 {
#                     "name": "DR Congo",
#                     "value": 86727573
#                 },
#                 {
#                     "name": "Turkey",
#                     "value": 82961805
#                 },
#                 {
#                     "name": "Iran",
#                     "value": 82820766
#                 },
#                 {
#                     "name": "Germany",
#                     "value": 82438639
#                 },
#                 {
#                     "name": "Thailand",
#                     "value": 69306160
#                 },
#                 {
#                     "name": "United Kingdom",
#                     "value": 66959016
#                 },
#                 {
#                     "name": "France",
#                     "value": 65480710
#                 },
#                 {
#                     "name": "Tanzania",
#                     "value": 60913557
#                 },
#                 {
#                     "name": "Italy",
#                     "value": 59216525
#                 },
#                 {
#                     "name": "South Africa",
#                     "value": 58065097
#                 },
#                 {
#                     "name": "Myanmar",
#                     "value": 54336138
#                 },
#                 {
#                     "name": "Kenya",
#                     "value": 52214791
#                 },
#                 {
#                     "name": "South Korea",
#                     "value": 51339238
#                 },
#                 {
#                     "name": "Colombia",
#                     "value": 49849818
#                 },
#                 {
#                     "name": "Spain",
#                     "value": 46441049
#                 },
#                 {
#                     "name": "Uganda",
#                     "value": 45711874
#                 },
#                 {
#                     "name": "Argentina",
#                     "value": 45101781
#                 },
#                 {
#                     "name": "Ukraine",
#                     "value": 43795220
#                 },
#                 {
#                     "name": "Algeria",
#                     "value": 42679018
#                 },
#                 {
#                     "name": "Sudan",
#                     "value": 42514094
#                 },
#                 {
#                     "name": "Iraq",
#                     "value": 40412299
#                 },
#                 {
#                     "name": "Poland",
#                     "value": 38028278
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 37279811
#                 },
#                 {
#                     "name": "Afghanistan",
#                     "value": 37209007
#                 },
#                 {
#                     "name": "Morocco",
#                     "value": 36635156
#                 },
#                 {
#                     "name": "Saudi Arabia",
#                     "value": 34140662
#                 },
#                 {
#                     "name": "Peru",
#                     "value": 32933835
#                 },
#                 {
#                     "name": "Uzbekistan",
#                     "value": 32807368
#                 },
#                 {
#                     "name": "Venezuela",
#                     "value": 32779868
#                 },
#                 {
#                     "name": "Malaysia",
#                     "value": 32454455
#                 },
#                 {
#                     "name": "Angola",
#                     "value": 31787566
#                 },
#                 {
#                     "name": "Mozambique",
#                     "value": 31408823
#                 },
#                 {
#                     "name": "Ghana",
#                     "value": 30096970
#                 },
#                 {
#                     "name": "Nepal",
#                     "value": 29942018
#                 },
#                 {
#                     "name": "Yemen",
#                     "value": 29579986
#                 },
#                 {
#                     "name": "Madagascar",
#                     "value": 26969642
#                 },
#                 {
#                     "name": "North Korea",
#                     "value": 25727408
#                 },
#                 {
#                     "name": "C\u00f4te d'Ivoire",
#                     "value": 25531083
#                 },
#                 {
#                     "name": "Cameroon",
